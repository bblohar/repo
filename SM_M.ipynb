# %%
print('hello world')
# Out:
# hello world

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('default')

# %%
price=[48000,54000,57000,49000, 47000,45000]
year=[2015,2016,2017,2018,2019,2020]
plt.plot(price,year)

# %%
yash=pd.read_csv('/sharma-kohli.csv')
yash
# Out:
#    index  RG Sharma  V Kohli
# 0   2008        404      165
# 1   2009        362      246
# 2   2010        404      307
# 3   2011        372      557
# 4   2012        433      364
# 5   2013        538      639
# 6   2014        390      359
# 7   2015        482      505
# 8   2016        489      973
# 9   2017        333      308

# %%
 plt.plot(yash['index'],yash['V Kohli'],color='Red',linestyle='solid',linewidth=3,marker='D',markersize=10,label='Virat')
 plt.plot(yash['index'],yash['RG Sharma'],color='Blue',linestyle='dashdot',linewidth=2,marker='o',label='Rohit')

 plt.title('Rohit Sharma Vs Virat Kohli Career Comparison')
 plt.xlabel('Season')
 plt.ylabel('Runs Scored')

 plt.legend(loc='upper right')
